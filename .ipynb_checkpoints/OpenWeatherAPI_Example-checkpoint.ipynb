# %% [markdown]
# # API general information
#
# API key:
# - Your API key is 1953847a1db7b2070fcd10ee09add91c
# - Within the next couple of hours, it will be activated and ready to use
# - You can later create more API keys on your account page
# - Please, always use your API key in each API call
#
# Endpoint:
# - Please, use the endpoint api.openweathermap.org for your API calls
# - Example of API call:
# api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=1953847a1db7b2070fcd10ee09add91c
#
# Useful links:
# - API documentation https://openweathermap.org/api
# - Details of your plan https://openweathermap.org/price
# - Please, note that 16-days daily forecast and History API are not available for Free subscribers

# %%
import requests
import pandas as pd
import numpy as np
import json
import pprint
import time
import string

# %%
pd_location = pd.read_excel('population_CH_2021.xlsx')
df = pd_location[1:]
df.head()
# Out:
#                     Municipality  Population on 31 December
# 1                       - Zürich                    1564662
# 2            >> Bezirk Affoltern                      56370
# 3     ......0001 Aeugst am Albis                       1988
# 4  ......0002 Affoltern am Albis                      12404
# 5          ......0003 Bonstetten                       5632

# %%
# throwing away the strange characters
df['Municipality'] = df['Municipality'].str.split(' ', n=1).str[1]
# Out:
# <ipython-input-169-78093223db43>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Municipality'] = df['Municipality'].str.split(' ', n=1).str[1]

# %%
print(df['Municipality'])
# Out:
# 1                   Zürich
# 2         Bezirk Affoltern
# 3          Aeugst am Albis
# 4       Affoltern am Albis
# 5               Bonstetten
#                ...
# 2331          Vendlincourt
# 2332         Basse-Allaine
# 2333         Clos du Doubs
# 2334           Haute-Ajoie
# 2335            La Baroche
# Name: Municipality, Length: 2335, dtype: object

# %%
# Renaming columns
df = df.rename(columns={'Population on 31 December':'Population_End2021'})
df.head(50)
# Out:
#             Municipality  Population_End2021
# 1                 Zürich             1564662
# 2       Bezirk Affoltern               56370
# 3        Aeugst am Albis                1988
# 4     Affoltern am Albis               12404
# 5             Bonstetten                5632
# 6        Hausen am Albis                3852
# 7               Hedingen                3780
# 8        Kappel am Albis                1290
# 9                 Knonau                2445
# 10           Maschwanden                 641
# 11        Mettmenstetten                5570
# 12              Obfelden                5760
# 13             Ottenbach                2745
# 14            Rifferswil                1150
# 15             Stallikon                3825
# 16     Wettswil am Albis                5288
# 17    Bezirk Andelfingen               32136
# 18               Adlikon                 716
# 19           Benken (ZH)                 852
# 20        Berg am Irchel                 591
# 21        Buch am Irchel                1026
# 22               Dachsen                1945
# 23                  Dorf                 695
# 24           Feuerthalen                3764
# 25                Flaach                1441
# 26            Flurlingen                1516
# 27           Andelfingen                2227
# 28              Henggart                2304
# 29              Humlikon                 487
# 30      Kleinandelfingen                2133
# 31       Laufen-Uhwiesen                1782
# 32             Marthalen                1927
# 33              Ossingen                1696
# 34               Rheinau                1297
# 35  Thalheim an der Thur                 973
# 36             Trüllikon                1060
# 37             Truttikon                 451
# 38                Volken                 392
# 39             Stammheim                2861
# 40         Bezirk Bülach              158566
# 41          Bachenbülach                4224
# 42           Bassersdorf               11960
# 43                Bülach               22193
# 44             Dietlikon                7875
# 45               Eglisau                5506
# 46               Embrach                9870
# 47    Freienstein-Teufen                2397
# 48           Glattfelden                5350
# 49            Hochfelden                2013
# 50                  Höri                3031

# %%
# Selecting cities greater than 10K inhabitants
big_cities = df.loc[df['Population_End2021'] > 10000]
big_cities.reset_index(inplace=True)
big_cities
# Out:
#      index                     Municipality  Population_End2021
# 0        1                           Zürich             1564662
# 1        2                 Bezirk Affoltern               56370
# 2        4               Affoltern am Albis               12404
# 3       17               Bezirk Andelfingen               32136
# 4       40                    Bezirk Bülach              158566
# ..     ...                              ...                 ...
# 317   2279                             Jura               73798
# 318   2280             District de Delémont               39125
# 319   2288                         Delémont               12479
# 320   2300  District des Franches-Montagnes               10478
# 321   2314           District de Porrentruy               24195
#
# [322 rows x 3 columns]

# %%
# make list of row indices where 'gmail.com' is in any column
indices = big_cities['Municipality'].where(big_cities['Municipality'].apply(lambda x: x.str.contains('Bezirk'))).dropna(how='all').index.tolist()
indices
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-683e3fa27c77> in <module>
#       1 # make list of row indices where 'gmail.com' is in any column
# ----> 2 indices = big_cities['Municipality'].where(big_cities['Municipality'].apply(lambda x: x.str.contains('Bezirk'))).dropna(how='all').index.tolist()
#       3 indices
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-182-683e3fa27c77> in <lambda>(x)
#       1 # make list of row indices where 'gmail.com' is in any column
# ----> 2 indices = big_cities['Municipality'].where(big_cities['Municipality'].apply(lambda x: x.str.contains('Bezirk'))).dropna(how='all').index.tolist()
#       3 indices
#
# AttributeError: 'str' object has no attribute 'str'

# %%
big_cities['Municipality'] = big_cities['Municipality'].str.split('Bezirk ').str[1]
big_cities
# Out:
# <ipython-input-173-5b50a6c69327>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   big_cities['Municipality'] = big_cities['Municipality'].str.split('Bezirk ').str[1]
#      Municipality  Population_End2021
# 1             NaN             1564662
# 2       Affoltern               56370
# 4             NaN               12404
# 17    Andelfingen               32136
# 40         Bülach              158566
# ...           ...                 ...
# 2279          NaN               73798
# 2280          NaN               39125
# 2288          NaN               12479
# 2300          NaN               10478
# 2314          NaN               24195
#
# [322 rows x 2 columns]

# %%
print(len(big_cities))
big_cities
# Out:
# 322
#      index                     Municipality  Population_End2021
# 0        1                           Zürich             1564662
# 1        2                 Bezirk Affoltern               56370
# 2        4               Affoltern am Albis               12404
# 3       17               Bezirk Andelfingen               32136
# 4       40                    Bezirk Bülach              158566
# ..     ...                              ...                 ...
# 317   2279                             Jura               73798
# 318   2280             District de Delémont               39125
# 319   2288                         Delémont               12479
# 320   2300  District des Franches-Montagnes               10478
# 321   2314           District de Porrentruy               24195
#
# [322 rows x 3 columns]

# %%
target_cities = list(big_cities['Municipality'])
target_cities

# %%
# Replace with the city and country code you want to get the weather for
#city_names = ["Zermatt", "Andermatt", "Visp", "Oberwald", "Disentis/Mustér"]
API_KEY = "f929f8bae1cf9df1f10a9a2a99661e67"
location = target_cities.copy()
country_code = "CH"
units = "metric"

# %%
# Create empyt list for current weather
current_weather = []

for city_name in location:
    # Base URL for OpenWeather API
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name},{country_code}&units={units}&appid={API_KEY}"
       
    # Fetch the current weather data
    response = requests.get(url)
    data = json.loads(response.text)
    current_weather.append(data)

# %%
current_weather
# Out:
# [{'coord': {'lon': 8.55, 'lat': 47.3667},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.89,
#    'feels_like': 8.34,
#    'temp_min': 8.09,
#    'temp_max': 10.17,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437738,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376464,
#    'sunset': 1679420307},
#   'timezone': 3600,
#   'id': 2657896,
#   'name': 'Zurich',
#   'cod': 200},
#  {'coord': {'lon': 8.4744, 'lat': 47.2731},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 7.15,
#    'feels_like': 6.35,
#    'temp_min': 6.37,
#    'temp_max': 8.47,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437862,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376482,
#    'sunset': 1679420324},
#   'timezone': 3600,
#   'id': 6458818,
#   'name': 'Bezirk Affoltern',
#   'cod': 200},
#  {'coord': {'lon': 8.4513, 'lat': 47.2774},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.24,
#    'feels_like': 7.51,
#    'temp_min': 7.54,
#    'temp_max': 9.64,
#    'pressure': 1018,
#    'humidity': 85,
#    'sea_level': 1018,
#    'grnd_level': 959},
#   'visibility': 10000,
#   'wind': {'speed': 1.62, 'deg': 185, 'gust': 1.51},
#   'clouds': {'all': 84},
#   'dt': 1679437862,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376488,
#    'sunset': 1679420330},
#   'timezone': 3600,
#   'id': 2661842,
#   'name': 'Affoltern am Albis',
#   'cod': 200},
#  {'coord': {'lon': 8.75, 'lat': 47.5833},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.42,
#    'feels_like': 8.99,
#    'temp_min': 8.25,
#    'temp_max': 10.49,
#    'pressure': 1015,
#    'humidity': 75},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 189, 'gust': 1.48},
#   'clouds': {'all': 87},
#   'dt': 1679437862,
#   'sys': {'type': 2,
#    'id': 2010543,
#    'country': 'CH',
#    'sunrise': 1679376414,
#    'sunset': 1679420260},
#   'timezone': 3600,
#   'id': 2661751,
#   'name': 'Bezirk Andelfingen',
#   'cod': 200},
#  {'coord': {'lon': 8.5676, 'lat': 47.4971},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.29,
#    'feels_like': 7.65,
#    'temp_min': 7.11,
#    'temp_max': 9.34,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437863,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376459,
#    'sunset': 1679420303},
#   'timezone': 3600,
#   'id': 6458867,
#   'name': 'Bezirk Bülach',
#   'cod': 200},
#  {'coord': {'lon': 8.6285, 'lat': 47.4434},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.75,
#    'feels_like': 8.18,
#    'temp_min': 7.72,
#    'temp_max': 9.95,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437863,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376444,
#    'sunset': 1679420288},
#   'timezone': 3600,
#   'id': 2661599,
#   'name': 'Bassersdorf',
#   'cod': 200},
#  {'coord': {'lon': 8.5405, 'lat': 47.522},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 9.23,
#    'feels_like': 8.73,
#    'temp_min': 7.96,
#    'temp_max': 10.2,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437568,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376465,
#    'sunset': 1679420310},
#   'timezone': 3600,
#   'id': 2661338,
#   'name': 'Bülach',
#   'cod': 200},
#  {'coord': {'lon': 8.5849, 'lat': 47.4515},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.86,
#    'feels_like': 8.31,
#    'temp_min': 7.98,
#    'temp_max': 10.06,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437863,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376455,
#    'sunset': 1679420299},
#   'timezone': 3600,
#   'id': 2660127,
#   'name': 'Kloten',
#   'cod': 200},
#  {'coord': {'lon': 8.5759, 'lat': 47.4317},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.85,
#    'feels_like': 8.29,
#    'temp_min': 7.86,
#    'temp_max': 10.05,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437863,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376457,
#    'sunset': 1679420301},
#   'timezone': 3600,
#   'id': 2659292,
#   'name': 'Opfikon',
#   'cod': 200},
#  {'coord': {'lon': 8.5967, 'lat': 47.415},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.7,
#    'feels_like': 8.12,
#    'temp_min': 7.77,
#    'temp_max': 9.96,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437863,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376452,
#    'sunset': 1679420296},
#   'timezone': 3600,
#   'id': 2658060,
#   'name': 'Wallisellen',
#   'cod': 200},
#  {'coord': {'lon': 8.4563, 'lat': 47.4718},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.74,
#    'feels_like': 8.17,
#    'temp_min': 7.55,
#    'temp_max': 9.73,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437863,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376486,
#    'sunset': 1679420330},
#   'timezone': 3600,
#   'id': 6458865,
#   'name': 'Dielsdorf',
#   'cod': 200},
#  {'coord': {'lon': 8.4687, 'lat': 47.4341},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.96,
#    'feels_like': 7.54,
#    'temp_min': 7.98,
#    'temp_max': 10.06,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 2.57, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437286,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376483,
#    'sunset': 1679420327},
#   'timezone': 3600,
#   'id': 2659083,
#   'name': 'Regensdorf',
#   'cod': 200},
#  {'coord': {'lon': 8.8343, 'lat': 47.2965},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.17,
#    'feels_like': 7.52,
#    'temp_min': 7.21,
#    'temp_max': 9.71,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437863,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376396,
#    'sunset': 1679420238},
#   'timezone': 3600,
#   'id': 6458797,
#   'name': 'Bezirk Hinwil',
#   'cod': 200},
#  {'coord': {'lon': 8.7686, 'lat': 47.3025},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.51,
#    'feels_like': 7.91,
#    'temp_min': 7.53,
#    'temp_max': 10.14,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437863,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376412,
#    'sunset': 1679420254},
#   'timezone': 3600,
#   'id': 7285946,
#   'name': 'Gossau (ZH)',
#   'cod': 200},
#  {'coord': {'lon': 8.8439, 'lat': 47.2943},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.06,
#    'feels_like': 7.39,
#    'temp_min': 7.08,
#    'temp_max': 9.58,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437863,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376394,
#    'sunset': 1679420236},
#   'timezone': 3600,
#   'id': 2660338,
#   'name': 'Hinwil',
#   'cod': 200},
#  {'coord': {'lon': 8.8655, 'lat': 47.2583},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.44,
#    'feels_like': 8.44,
#    'temp_min': 7.45,
#    'temp_max': 9.16,
#    'pressure': 1016,
#    'humidity': 80},
#   'visibility': 10000,
#   'wind': {'speed': 0.89, 'deg': 74, 'gust': 1.79},
#   'clouds': {'all': 98},
#   'dt': 1679437864,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376389,
#    'sunset': 1679420230},
#   'timezone': 3600,
#   'id': 7287001,
#   'name': 'Rüti (ZH)',
#   'cod': 200},
#  {'coord': {'lon': 8.9209, 'lat': 47.2871},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 7.08,
#    'feels_like': 7.08,
#    'temp_min': 6.08,
#    'temp_max': 7.79,
#    'pressure': 1016,
#    'humidity': 75},
#   'visibility': 10000,
#   'wind': {'speed': 0.89, 'deg': 74, 'gust': 1.79},
#   'clouds': {'all': 99},
#   'dt': 1679437864,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376375,
#    'sunset': 1679420217},
#   'timezone': 3600,
#   'id': 7287524,
#   'name': 'Wald (ZH)',
#   'cod': 200},
#  {'coord': {'lon': 8.8047, 'lat': 47.3243},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.23,
#    'feels_like': 7.59,
#    'temp_min': 7.33,
#    'temp_max': 9.82,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376403,
#    'sunset': 1679420245},
#   'timezone': 3600,
#   'id': 7287564,
#   'name': 'Wetzikon (ZH)',
#   'cod': 200},
#  {'coord': {'lon': 8.597, 'lat': 47.2577},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.69,
#    'feels_like': 8.11,
#    'temp_min': 7.9,
#    'temp_max': 10,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376453,
#    'sunset': 1679420295},
#   'timezone': 3600,
#   'id': 6458847,
#   'name': 'Bezirk Horgen',
#   'cod': 200},
#  {'coord': {'lon': 8.5246, 'lat': 47.31},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.62,
#    'feels_like': 8.03,
#    'temp_min': 7.79,
#    'temp_max': 9.89,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376470,
#    'sunset': 1679420312},
#   'timezone': 3600,
#   'id': 2661861,
#   'name': 'Adliswil',
#   'cod': 200},
#  {'coord': {'lon': 8.6969, 'lat': 47.2062},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.4,
#    'feels_like': 7.39,
#    'temp_min': 7.48,
#    'temp_max': 10.09,
#    'pressure': 1018,
#    'humidity': 80,
#    'sea_level': 1018,
#    'grnd_level': 958},
#   'visibility': 10000,
#   'wind': {'speed': 1.93, 'deg': 171, 'gust': 1.64},
#   'clouds': {'all': 95},
#   'dt': 1679437864,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376430,
#    'sunset': 1679420270},
#   'timezone': 3600,
#   'id': 2659050,
#   'name': 'Richterswil',
#   'cod': 200},
#  {'coord': {'lon': 8.5635, 'lat': 47.2918},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.49,
#    'feels_like': 7.88,
#    'temp_min': 7.72,
#    'temp_max': 9.82,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376461,
#    'sunset': 1679420303},
#   'timezone': 3600,
#   'id': 2658388,
#   'name': 'Thalwil',
#   'cod': 200},
#  {'coord': {'lon': 8.6687, 'lat': 47.2268},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.47,
#    'feels_like': 7.86,
#    'temp_min': 7.6,
#    'temp_max': 10.21,
#    'pressure': 1016,
#    'humidity': 80},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376436,
#    'sunset': 1679420277},
#   'timezone': 3600,
#   'id': 2658082,
#   'name': 'Wädenswil',
#   'cod': 200},
#  {'coord': {'lon': 8.6003, 'lat': 47.2558},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.51,
#    'feels_like': 7.91,
#    'temp_min': 7.72,
#    'temp_max': 9.82,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376452,
#    'sunset': 1679420294},
#   'timezone': 3600,
#   'id': 2660305,
#   'name': 'Horgen',
#   'cod': 200},
#  {'coord': {'lon': 8.6333, 'lat': 47.2833},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.12,
#    'feels_like': 7.46,
#    'temp_min': 7.28,
#    'temp_max': 9.38,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437864,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376444,
#    'sunset': 1679420286},
#   'timezone': 3600,
#   'id': 2659702,
#   'name': 'Bezirk Meilen',
#   'cod': 200},
#  {'coord': {'lon': 8.6122, 'lat': 47.3197},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 7.62,
#    'feels_like': 6.89,
#    'temp_min': 6.77,
#    'temp_max': 8.95,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376449,
#    'sunset': 1679420291},
#   'timezone': 3600,
#   'id': 7286229,
#   'name': 'Küsnacht (ZH)',
#   'cod': 200},
#  {'coord': {'lon': 8.6989, 'lat': 47.2569},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.5,
#    'feels_like': 7.89,
#    'temp_min': 7.6,
#    'temp_max': 10.21,
#    'pressure': 1016,
#    'humidity': 80},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376429,
#    'sunset': 1679420270},
#   'timezone': 3600,
#   'id': 2659772,
#   'name': 'Männedorf',
#   'cod': 200},
#  {'coord': {'lon': 8.6462, 'lat': 47.2723},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.66,
#    'feels_like': 8.08,
#    'temp_min': 7.81,
#    'temp_max': 9.91,
#    'pressure': 1016,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376441,
#    'sunset': 1679420283},
#   'timezone': 3600,
#   'id': 2659703,
#   'name': 'Meilen',
#   'cod': 200},
#  {'coord': {'lon': 8.7234, 'lat': 47.2425},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.92,
#    'feels_like': 8.37,
#    'temp_min': 7.97,
#    'temp_max': 10.58,
#    'pressure': 1016,
#    'humidity': 80},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376423,
#    'sunset': 1679420264},
#   'timezone': 3600,
#   'id': 2658518,
#   'name': 'Stäfa',
#   'cod': 200},
#  {'coord': {'lon': 8.5741, 'lat': 47.3402},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.53,
#    'feels_like': 7.93,
#    'temp_min': 7.68,
#    'temp_max': 9.86,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376458,
#    'sunset': 1679420301},
#   'timezone': 3600,
#   'id': 2657912,
#   'name': 'Zollikon',
#   'cod': 200},
#  {'coord': {'lon': 8.7721, 'lat': 47.4091},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 7.13,
#    'feels_like': 6.33,
#    'temp_min': 6.07,
#    'temp_max': 8.73,
#    'pressure': 993,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 2,
#    'id': 2080788,
#    'country': 'CH',
#    'sunrise': 1679376410,
#    'sunset': 1679420254},
#   'timezone': 3600,
#   'id': 6458852,
#   'name': 'Bezirk Pfäffikon',
#   'cod': 200},
#  {'coord': {'lon': 8.792, 'lat': 47.3645},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.13,
#    'feels_like': 7.47,
#    'temp_min': 7.25,
#    'temp_max': 9.75,
#    'pressure': 984,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 2,
#    'id': 2080788,
#    'country': 'CH',
#    'sunrise': 1679376406,
#    'sunset': 1679420248},
#   'timezone': 3600,
#   'id': 2659219,
#   'name': 'Pfaeffikon',
#   'cod': 200},
#  {'coord': {'lon': 8.716, 'lat': 47.4229},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.38,
#    'feels_like': 7.76,
#    'temp_min': 7.36,
#    'temp_max': 9.6,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376424,
#    'sunset': 1679420267},
#   'timezone': 3600,
#   'id': 7286135,
#   'name': 'Illnau-Effretikon',
#   'cod': 200},
#  {'coord': {'lon': 8.6765, 'lat': 47.3579},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.79,
#    'feels_like': 8.23,
#    'temp_min': 7.93,
#    'temp_max': 10.12,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376433,
#    'sunset': 1679420276},
#   'timezone': 3600,
#   'id': 6458751,
#   'name': 'Bezirk Uster',
#   'cod': 200},
#  {'coord': {'lon': 8.6187, 'lat': 47.3972},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.81,
#    'feels_like': 8.25,
#    'temp_min': 7.9,
#    'temp_max': 10.09,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376447,
#    'sunset': 1679420290},
#   'timezone': 3600,
#   'id': 2660971,
#   'name': 'Dübendorf',
#   'cod': 200},
#  {'coord': {'lon': 8.66, 'lat': 47.3361},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 7.89,
#    'feels_like': 7.2,
#    'temp_min': 7.03,
#    'temp_max': 9.21,
#    'pressure': 1016,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437865,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376438,
#    'sunset': 1679420280},
#   'timezone': 3600,
#   'id': 7286464,
#   'name': 'Maur',
#   'cod': 200},
#  {'coord': {'lon': 8.7209, 'lat': 47.3471},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.56,
#    'feels_like': 7.96,
#    'temp_min': 7.77,
#    'temp_max': 10.27,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437689,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376423,
#    'sunset': 1679420265},
#   'timezone': 3600,
#   'id': 2658216,
#   'name': 'Uster',
#   'cod': 200},
#  {'coord': {'lon': 8.6909, 'lat': 47.3902},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.5,
#    'feels_like': 7.89,
#    'temp_min': 7.59,
#    'temp_max': 9.77,
#    'pressure': 1016,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437866,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376430,
#    'sunset': 1679420273},
#   'timezone': 3600,
#   'id': 2658105,
#   'name': 'Volketswil / Volketswil (Dorf)',
#   'cod': 200},
#  {'coord': {'lon': 8.769, 'lat': 47.5078},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.77,
#    'feels_like': 8.2,
#    'temp_min': 7.71,
#    'temp_max': 9.95,
#    'pressure': 999,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437770,
#   'sys': {'type': 2,
#    'id': 2010543,
#    'country': 'CH',
#    'sunrise': 1679376410,
#    'sunset': 1679420255},
#   'timezone': 3600,
#   'id': 6458808,
#   'name': 'Bezirk Winterthur',
#   'cod': 200},
#  {'coord': {'lon': 8.75, 'lat': 47.5},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.82,
#    'feels_like': 8.26,
#    'temp_min': 7.77,
#    'temp_max': 10.01,
#    'pressure': 999,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437561,
#   'sys': {'type': 2,
#    'id': 2010543,
#    'country': 'CH',
#    'sunrise': 1679376415,
#    'sunset': 1679420259},
#   'timezone': 3600,
#   'id': 2657970,
#   'name': 'Winterthur',
#   'cod': 200},
#  {'coord': {'lon': 8.4426, 'lat': 47.388},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.36,
#    'feels_like': 7.73,
#    'temp_min': 7.44,
#    'temp_max': 9.52,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437800,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376489,
#    'sunset': 1679420333},
#   'timezone': 3600,
#   'id': 6458760,
#   'name': 'Bezirk Dietikon',
#   'cod': 200},
#  {'coord': {'lon': 8.4002, 'lat': 47.4016},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 9.21,
#    'feels_like': 8.71,
#    'temp_min': 8.12,
#    'temp_max': 10.31,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437866,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376499,
#    'sunset': 1679420343},
#   'timezone': 3600,
#   'id': 2661015,
#   'name': 'Dietikon',
#   'cod': 200},
#  {'coord': {'lon': 8.4476, 'lat': 47.3967},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 9.18,
#    'feels_like': 8.67,
#    'temp_min': 8.14,
#    'temp_max': 10.33,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437866,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376488,
#    'sunset': 1679420331},
#   'timezone': 3600,
#   'id': 2658724,
#   'name': 'Schlieren',
#   'cod': 200},
#  {'coord': {'lon': 8.4258, 'lat': 47.3851},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 9.02,
#    'feels_like': 8.49,
#    'temp_min': 8.1,
#    'temp_max': 10.18,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1679437629,
#   'sys': {'type': 1,
#    'id': 6941,
#    'country': 'CH',
#    'sunrise': 1679376493,
#    'sunset': 1679420337},
#   'timezone': 3600,
#   'id': 2659332,
#   'name': 'Urdorf',
#   'cod': 200},
#  {'coord': {'lon': 8.5432, 'lat': 47.3711},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.96,
#    'feels_like': 8.42,
#    'temp_min': 8.04,
#    'temp_max': 10.23,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437866,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376465,
#    'sunset': 1679420308},
#   'timezone': 3600,
#   'id': 6458798,
#   'name': 'Zürich District',
#   'cod': 200},
#  {'coord': {'lon': 8.55, 'lat': 47.3667},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 8.89,
#    'feels_like': 8.34,
#    'temp_min': 8.09,
#    'temp_max': 10.17,
#    'pressure': 1016,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 140},
#   'clouds': {'all': 40},
#   'dt': 1679437738,
#   'sys': {'type': 1,
#    'id': 6932,
#    'country': 'CH',
#    'sunrise': 1679376464,
#    'sunset': 1679420307},
#   'timezone': 3600,
#   'id': 2657896,
#   'name': 'Zurich',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.2441, 'lat': 47.1324},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.92,
#    'feels_like': 9.92,
#    'temp_min': 8.94,
#    'temp_max': 10.81,
#    'pressure': 1015,
#    'humidity': 85},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437727,
#   'sys': {'type': 2,
#    'id': 2020638,
#    'country': 'CH',
#    'sunrise': 1679376778,
#    'sunset': 1679420619},
#   'timezone': 3600,
#   'id': 2661513,
#   'name': 'Biel/Bienne',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.3066, 'lat': 47.0741},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.31,
#    'feels_like': 9.31,
#    'temp_min': 8.42,
#    'temp_max': 10.76,
#    'pressure': 1059,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437867,
#   'sys': {'type': 2,
#    'id': 2006822,
#    'country': 'CH',
#    'sunrise': 1679376764,
#    'sunset': 1679420603},
#   'timezone': 3600,
#   'id': 2659808,
#   'name': 'Lyss',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.7961, 'lat': 47.2153},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.04,
#    'feels_like': 9.04,
#    'temp_min': 7.66,
#    'temp_max': 9.44,
#    'pressure': 1018,
#    'humidity': 84,
#    'sea_level': 1018,
#    'grnd_level': 961},
#   'visibility': 10000,
#   'wind': {'speed': 1.05, 'deg': 220, 'gust': 1.16},
#   'clouds': {'all': 73},
#   'dt': 1679437867,
#   'sys': {'type': 2,
#    'id': 222963,
#    'country': 'CH',
#    'sunrise': 1679376645,
#    'sunset': 1679420487},
#   'timezone': 3600,
#   'id': 2660034,
#   'name': 'Langenthal',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.6279, 'lat': 47.059},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.61,
#    'feels_like': 8.61,
#    'temp_min': 7.82,
#    'temp_max': 9.07,
#    'pressure': 1016,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437867,
#   'sys': {'type': 2,
#    'id': 216973,
#    'country': 'CH',
#    'sunrise': 1679376687,
#    'sunset': 1679420526},
#   'timezone': 3600,
#   'id': 2661321,
#   'name': 'Burgdorf',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.4474, 'lat': 46.9481},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.89,
#    'feels_like': 7.85,
#    'temp_min': 7.95,
#    'temp_max': 10.23,
#    'pressure': 1016,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 2.06, 'deg': 100},
#   'clouds': {'all': 75},
#   'dt': 1679437363,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376731,
#    'sunset': 1679420569},
#   'timezone': 3600,
#   'id': 2661552,
#   'name': 'Bern',
#   'cod': 200},
#  {'coord': {'lon': 7.4146, 'lat': 46.9244},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.3,
#    'feels_like': 8.3,
#    'temp_min': 7.55,
#    'temp_max': 9.82,
#    'pressure': 1016,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437867,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376739,
#    'sunset': 1679420576},
#   'timezone': 3600,
#   'id': 2660119,
#   'name': 'Köniz',
#   'cod': 200},
#  {'coord': {'lon': 7.4866, 'lat': 46.9312},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.47,
#    'feels_like': 8.47,
#    'temp_min': 7.74,
#    'temp_max': 10.02,
#    'pressure': 1016,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437867,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376721,
#    'sunset': 1679420559},
#   'timezone': 3600,
#   'id': 2659532,
#   'name': 'Muri bei Bern',
#   'cod': 200},
#  {'coord': {'lon': 7.4581, 'lat': 46.999},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.69,
#    'feels_like': 8.69,
#    'temp_min': 8.11,
#    'temp_max': 9.32,
#    'pressure': 1094,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.29, 'deg': 173, 'gust': 1.3},
#   'clouds': {'all': 67},
#   'dt': 1679437867,
#   'sys': {'type': 2,
#    'id': 2006822,
#    'country': 'CH',
#    'sunrise': 1679376728,
#    'sunset': 1679420567},
#   'timezone': 3600,
#   'id': 2657913,
#   'name': 'Zollikofen',
#   'cod': 200},
#  {'coord': {'lon': 7.4828, 'lat': 46.9743},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.98,
#    'feels_like': 8.98,
#    'temp_min': 8.26,
#    'temp_max': 10.06,
#    'pressure': 1018,
#    'humidity': 86,
#    'sea_level': 1018,
#    'grnd_level': 953},
#   'visibility': 10000,
#   'wind': {'speed': 1.24, 'deg': 174, 'gust': 1.13},
#   'clouds': {'all': 82},
#   'dt': 1679437800,
#   'sys': {'type': 2,
#    'id': 2006822,
#    'country': 'CH',
#    'sunrise': 1679376722,
#    'sunset': 1679420560},
#   'timezone': 3600,
#   'id': 6424338,
#   'name': 'Ittigen',
#   'cod': 200},
#  {'coord': {'lon': 7.4956, 'lat': 46.9559},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.32,
#    'feels_like': 8.32,
#    'temp_min': 7.55,
#    'temp_max': 9.83,
#    'pressure': 1016,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376719,
#    'sunset': 1679420557},
#   'timezone': 3600,
#   'id': 7286761,
#   'name': 'Ostermundigen',
#   'cod': 200},
#  {'coord': {'lon': 7.4504, 'lat': 47.0218},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.73,
#    'feels_like': 8.73,
#    'temp_min': 8.17,
#    'temp_max': 9.38,
#    'pressure': 1062,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 2,
#    'id': 2006822,
#    'country': 'CH',
#    'sunrise': 1679376730,
#    'sunset': 1679420569},
#   'timezone': 3600,
#   'id': 2659552,
#   'name': 'Münchenbuchsee',
#   'cod': 200},
#  {'coord': {'lon': 7.561, 'lat': 46.873},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.61,
#    'feels_like': 8.61,
#    'temp_min': 7.8,
#    'temp_max': 9.49,
#    'pressure': 1016,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376704,
#    'sunset': 1679420541},
#   'timezone': 3600,
#   'id': 2659546,
#   'name': 'Münsingen',
#   'cod': 200},
#  {'coord': {'lon': 7.5631, 'lat': 46.9298},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.29,
#    'feels_like': 8.29,
#    'temp_min': 7.52,
#    'temp_max': 9.21,
#    'pressure': 1016,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376703,
#    'sunset': 1679420541},
#   'timezone': 3600,
#   'id': 2657954,
#   'name': 'Worb',
#   'cod': 200},
#  {'coord': {'lon': 7.4983, 'lat': 46.8913},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.72,
#    'feels_like': 8.72,
#    'temp_min': 7.94,
#    'temp_max': 10.21,
#    'pressure': 1016,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437799,
#   'sys': {'type': 1,
#    'id': 6937,
#    'country': 'CH',
#    'sunrise': 1679376719,
#    'sunset': 1679420556},
#   'timezone': 3600,
#   'id': 2661563,
#   'name': 'Belp',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.6325, 'lat': 46.7781},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.48,
#    'feels_like': 6.9,
#    'temp_min': 6.93,
#    'temp_max': 9.84,
#    'pressure': 1014,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 2.68, 'deg': 169, 'gust': 3.13},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 2,
#    'id': 2008883,
#    'country': 'CH',
#    'sunrise': 1679376687,
#    'sunset': 1679420523},
#   'timezone': 3600,
#   'id': 2658494,
#   'name': 'Steffisburg',
#   'cod': 200},
#  {'coord': {'lon': 7.6217, 'lat': 46.7512},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.68,
#    'feels_like': 8.33,
#    'temp_min': 7.09,
#    'temp_max': 10.48,
#    'pressure': 1013,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.34, 'deg': 173, 'gust': 3.13},
#   'clouds': {'all': 98},
#   'dt': 1679437560,
#   'sys': {'type': 2,
#    'id': 2008883,
#    'country': 'CH',
#    'sunrise': 1679376690,
#    'sunset': 1679420526},
#   'timezone': 3600,
#   'id': 2658377,
#   'name': 'Thun',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 7.6911, 'lat': 46.6847},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.46,
#    'feels_like': 6.87,
#    'temp_min': 6.85,
#    'temp_max': 9.76,
#    'pressure': 1013,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 2.68, 'deg': 169, 'gust': 3.13},
#   'clouds': {'all': 86},
#   'dt': 1679437868,
#   'sys': {'type': 2,
#    'id': 2002821,
#    'country': 'CH',
#    'sunrise': 1679376674,
#    'sunset': 1679420509},
#   'timezone': 3600,
#   'id': 2658536,
#   'name': 'Spiez',
#   'cod': 200},
#  {'coord': {'lon': 7.9231, 'lat': 46.673},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 3.14,
#    'feels_like': 3.14,
#    'temp_min': 1.73,
#    'temp_max': 4.64,
#    'pressure': 1017,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 1,
#    'id': 6934,
#    'country': 'CH',
#    'sunrise': 1679376618,
#    'sunset': 1679420453},
#   'timezone': 3600,
#   'id': 6458842,
#   'name': 'Verwaltungskreis Interlaken-Oberhasli',
#   'cod': 200},
#  {'coord': {'lon': 8.3064, 'lat': 47.0505},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.49,
#    'feels_like': 7.88,
#    'temp_min': 7.93,
#    'temp_max': 9.69,
#    'pressure': 1017,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 2,
#    'id': 2034458,
#    'country': 'CH',
#    'sunrise': 1679376524,
#    'sunset': 1679420363},
#   'timezone': 3600,
#   'id': 2659811,
#   'name': 'Lucerne',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 8.3064, 'lat': 47.0505},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.49,
#    'feels_like': 7.88,
#    'temp_min': 7.93,
#    'temp_max': 9.69,
#    'pressure': 1017,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1679437868,
#   'sys': {'type': 2,
#    'id': 2034458,
#    'country': 'CH',
#    'sunrise': 1679376524,
#    'sunset': 1679420363},
#   'timezone': 3600,
#   'id': 2659811,
#   'name': 'Lucerne',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 8.3404, 'lat': 47.0794},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.57,
#    'feels_like': 7.97,
#    'temp_min': 7.85,
#    'temp_max': 9.61,
#    'pressure': 1017,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1679437784,
#   'sys': {'type': 1,
#    'id': 6933,
#    'country': 'CH',
#    'sunrise': 1679376516,
#    'sunset': 1679420355},
#   'timezone': 3600,
#   'id': 2660953,
#   'name': 'Ebikon',
#   'cod': 200},
#  {'coord': {'lon': 8.3096, 'lat': 47.0169},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.43,
#    'feels_like': 7.81,
#    'temp_min': 7.88,
#    'temp_max': 9.64,
#    'pressure': 1017,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 240},
#   'clouds': {'all': 100},
#   'dt': 1679437869,
#   'sys': {'type': 2,
#    'id': 2034458,
#    'country': 'CH',
#    'sunrise': 1679376524,
#    'sunset': 1679420362},
#   'timezone': 3600,
#   'id': 2660298,
#   'name': 'Horw',
#   'cod': 200},
#  {'coord': {'lon': 8.2763, 'lat': 47.0354},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.06,
#    'feels_like': 7.39,
#    'temp_min': 7.52,
#    'temp_max': 9.28,
#    'pressure': 1017,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1679437869,
#   'sys': {'type': 2,
#    'id': 2034458,
#    'country': 'CH',
#    'sunrise': 1679376531,
#    'sunset': 1679420370},
#   'timezone': 3600,
#   'id': 2660104,
#   'name': 'Kriens',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 8.3048, 'lat': 47.0811},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.56,
#    'feels_like': 7.96,
#    'temp_min': 7.96,
#    'temp_max': 9.72,
#    'pressure': 1017,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1679437869,
#   'sys': {'type': 1,
#    'id': 6933,
#    'country': 'CH',
#    'sunrise': 1679376524,
#    'sunset': 1679420364},
#   'timezone': 3600,
#   'id': 2660911,
#   'name': 'Emmen',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 8.1, 'lat': 47.1667},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.32,
#    'feels_like': 8.32,
#    'temp_min': 7.41,
#    'temp_max': 9.17,
#    'pressure': 1017,
#    'humidity': 89},
#   'visibility': 10000,
#   'wind': {'speed': 0.51, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437869,
#   'sys': {'type': 2,
#    'id': 2034458,
#    'country': 'CH',
#    'sunrise': 1679376573,
#    'sunset': 1679420413},
#   'timezone': 3600,
#   'id': 2658440,
#   'name': 'Sursee',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 8.6388, 'lat': 46.8304},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.35,
#    'feels_like': 8.9,
#    'temp_min': 7.58,
#    'temp_max': 10.74,
#    'pressure': 1020,
#    'humidity': 70,
#    'sea_level': 1020,
#    'grnd_level': 961},
#   'visibility': 10000,
#   'wind': {'speed': 1.51, 'deg': 183, 'gust': 1.49},
#   'clouds': {'all': 99},
#   'dt': 1679437870,
#   'sys': {'type': 2,
#    'id': 2009771,
#    'country': 'CH',
#    'sunrise': 1679376446,
#    'sunset': 1679420282},
#   'timezone': 3600,
#   'id': 6458799,
#   'name': 'Uri',
#   'cod': 200},
#  {'coord': {'lon': 8.75, 'lat': 46.8333},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 1.71,
#    'feels_like': 1.71,
#    'temp_min': -0.33,
#    'temp_max': 2.83,
#    'pressure': 1020,
#    'humidity': 69,
#    'sea_level': 1020,
#    'grnd_level': 827},
#   'visibility': 10000,
#   'wind': {'speed': 1.21, 'deg': 184, 'gust': 1.36},
#   'clouds': {'all': 100},
#   'dt': 1679437626,
#   'sys': {'type': 2,
#    'id': 2009771,
#    'country': 'CH',
#    'sunrise': 1679376419,
#    'sunset': 1679420255},
#   'timezone': 3600,
#   'id': 2658226,
#   'name': 'Canton of Uri',
#   'cod': 200},
#  {'coord': {'lon': 8.6561, 'lat': 47.0279},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 7.63,
#    'feels_like': 5.97,
#    'temp_min': 6.81,
#    'temp_max': 9.85,
#    'pressure': 1019,
#    'humidity': 76,
#    'sea_level': 1019,
#    'grnd_level': 945},
#   'visibility': 10000,
#   'wind': {'speed': 2.56, 'deg': 161, 'gust': 2.01},
#   'clouds': {'all': 100},
#   'dt': 1679437560,
#   'sys': {'type': 1,
#    'id': 6938,
#    'country': 'CH',
#    'sunrise': 1679376441,
#    'sunset': 1679420279},
#   'timezone': 3600,
#   'id': 2658665,
#   'name': 'Schwyz',
#   'cod': 200},
#  {'coord': {'lon': 8.7601, 'lat': 47.1079},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 5.46,
#    'feels_like': 3.52,
#    'temp_min': 4.34,
#    'temp_max': 6.95,
#    'pressure': 1019,
#    'humidity': 76,
#    'sea_level': 1019,
#    'grnd_level': 904},
#   'visibility': 10000,
#   'wind': {'speed': 2.41, 'deg': 165, 'gust': 1.9},
#   'clouds': {'all': 99},
#   'dt': 1679437870,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376415,
#    'sunset': 1679420254},
#   'timezone': 3600,
#   'id': 6458878,
#   'name': 'Bezirk Einsiedeln',
#   'cod': 200},
#  {'coord': {'lon': 8.75, 'lat': 47.1167},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 5.43,
#    'feels_like': 3.5,
#    'temp_min': 4.33,
#    'temp_max': 6.94,
#    'pressure': 1019,
#    'humidity': 76,
#    'sea_level': 1019,
#    'grnd_level': 903},
#   'visibility': 10000,
#   'wind': {'speed': 2.39, 'deg': 165, 'gust': 1.89},
#   'clouds': {'all': 99},
#   'dt': 1679437870,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376417,
#    'sunset': 1679420257},
#   'timezone': 3600,
#   'id': 2660925,
#   'name': 'Einsiedeln',
#   'cod': 200},
#  {'coord': {'lon': 8.7396, 'lat': 47.1904},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.09,
#    'feels_like': 6.94,
#    'temp_min': 7.09,
#    'temp_max': 8.9,
#    'pressure': 1018,
#    'humidity': 80,
#    'sea_level': 1018,
#    'grnd_level': 951},
#   'visibility': 10000,
#   'wind': {'speed': 2.03, 'deg': 168, 'gust': 1.68},
#   'clouds': {'all': 97},
#   'dt': 1679437870,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376419,
#    'sunset': 1679420260},
#   'timezone': 3600,
#   'id': 6458848,
#   'name': 'Bezirk Höfe',
#   'cod': 200},
#  {'coord': {'lon': 8.7584, 'lat': 47.2053},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.08,
#    'feels_like': 8.15,
#    'temp_min': 8.07,
#    'temp_max': 9.88,
#    'pressure': 1018,
#    'humidity': 80,
#    'sea_level': 1018,
#    'grnd_level': 969},
#   'visibility': 10000,
#   'wind': {'speed': 1.96, 'deg': 169, 'gust': 1.64},
#   'clouds': {'all': 98},
#   'dt': 1679437870,
#   'sys': {'type': 2,
#    'id': 2006037,
#    'country': 'CH',
#    'sunrise': 1679376415,
#    'sunset': 1679420255},
#   'timezone': 3600,
#   'id': 2660721,
#   'name': 'Freienbach',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 8.4452, 'lat': 47.0813},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
# ...
#   'clouds': {'all': 100},
#   'dt': 1679437804,
#   'sys': {'type': 1,
#    'id': 6935,
#    'country': 'CH',
#    'sunrise': 1679376878,
#    'sunset': 1679420716},
#   'timezone': 3600,
#   'id': 2659495,
#   'name': 'Canton of Neuchâtel',
#   'cod': 200},
#  {'coord': {'lon': 6.8333, 'lat': 46.9167},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.39,
#    'feels_like': 9.55,
#    'temp_min': 9.59,
#    'temp_max': 10.91,
#    'pressure': 1017,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 100},
#   'dt': 1679437805,
#   'sys': {'type': 1,
#    'id': 6935,
#    'country': 'CH',
#    'sunrise': 1679376878,
#    'sunset': 1679420716},
#   'timezone': 3600,
#   'id': 2659495,
#   'name': 'Canton of Neuchâtel',
#   'cod': 200},
#  {'coord': {'lon': 6.8259, 'lat': 47.0999},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 6.89,
#    'feels_like': 6.89,
#    'temp_min': 5.3,
#    'temp_max': 7.17,
#    'pressure': 1017,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 240},
#   'clouds': {'all': 0},
#   'dt': 1679437892,
#   'sys': {'type': 1,
#    'id': 6927,
#    'country': 'CH',
#    'sunrise': 1679376879,
#    'sunset': 1679420719},
#   'timezone': 3600,
#   'id': 2660076,
#   'name': 'La Chaux-de-Fonds',
#   'cod': 200},
#  {'coord': {'lon': 6.7523, 'lat': 47.0595},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 7.25,
#    'feels_like': 7.25,
#    'temp_min': 5.93,
#    'temp_max': 7.47,
#    'pressure': 1017,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 240},
#   'clouds': {'all': 0},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6927,
#    'country': 'CH',
#    'sunrise': 1679376897,
#    'sunset': 1679420736},
#   'timezone': 3600,
#   'id': 2659960,
#   'name': 'Le Locle',
#   'cod': 200},
#  {'coord': {'lon': 6.8333, 'lat': 46.9167},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.39,
#    'feels_like': 9.55,
#    'temp_min': 9.59,
#    'temp_max': 10.91,
#    'pressure': 1017,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 100},
#   'dt': 1679437804,
#   'sys': {'type': 1,
#    'id': 6935,
#    'country': 'CH',
#    'sunrise': 1679376878,
#    'sunset': 1679420716},
#   'timezone': 3600,
#   'id': 2659495,
#   'name': 'Canton of Neuchâtel',
#   'cod': 200},
#  {'coord': {'lon': 6.9083, 'lat': 47.0401},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 8.41,
#    'feels_like': 8.41,
#    'temp_min': 6.53,
#    'temp_max': 8.87,
#    'pressure': 1017,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 240},
#   'clouds': {'all': 0},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6927,
#    'country': 'CH',
#    'sunrise': 1679376859,
#    'sunset': 1679420699},
#   'timezone': 3600,
#   'id': 6458812,
#   'name': 'Val-de-Ruz District',
#   'cod': 200},
#  {'coord': {'lon': 6.5631, 'lat': 46.9036},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 7.61,
#    'feels_like': 7.61,
#    'temp_min': 5.26,
#    'temp_max': 7.95,
#    'pressure': 1019,
#    'humidity': 90,
#    'sea_level': 1019,
#    'grnd_level': 916},
#   'visibility': 10000,
#   'wind': {'speed': 1.33, 'deg': 247, 'gust': 2.34},
#   'clouds': {'all': 80},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6927,
#    'country': 'CH',
#    'sunrise': 1679376943,
#    'sunset': 1679420781},
#   'timezone': 3600,
#   'id': 6458835,
#   'name': 'Val-de-Travers District',
#   'cod': 200},
#  {'coord': {'lon': 6.1457, 'lat': 46.2022},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.01,
#    'feels_like': 8.95,
#    'temp_min': 7.46,
#    'temp_max': 11.94,
#    'pressure': 1017,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437876,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377047,
#    'sunset': 1679420877},
#   'timezone': 3600,
#   'id': 2660646,
#   'name': 'Geneva',
#   'cod': 200},
#  {'coord': {'lon': 6.1667, 'lat': 46.1667},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.49,
#    'feels_like': 9.49,
#    'temp_min': 7.12,
#    'temp_max': 11.6,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377043,
#    'sunset': 1679420872},
#   'timezone': 3600,
#   'id': 2660645,
#   'name': 'Canton of Geneva',
#   'cod': 200},
#  {'coord': {'lon': 6.0754, 'lat': 46.1765},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.25,
#    'feels_like': 9.25,
#    'temp_min': 6.98,
#    'temp_max': 11.46,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437804,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377064,
#    'sunset': 1679420894},
#   'timezone': 3600,
#   'id': 2661547,
#   'name': 'Bernex',
#   'cod': 200},
#  {'coord': {'lon': 6.1404, 'lat': 46.1817},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.91,
#    'feels_like': 9.91,
#    'temp_min': 7.46,
#    'temp_max': 11.94,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377049,
#    'sunset': 1679420878},
#   'timezone': 3600,
#   'id': 7285435,
#   'name': 'Carouge (GE)',
#   'cod': 200},
#  {'coord': {'lon': 6.1864, 'lat': 46.1984},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.76,
#    'feels_like': 9.76,
#    'temp_min': 7.19,
#    'temp_max': 11.67,
#    'pressure': 1017,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377038,
#    'sunset': 1679420867},
#   'timezone': 3600,
#   'id': 3209498,
#   'name': 'Chêne-Bougeries',
#   'cod': 200},
#  {'coord': {'lon': 6.1457, 'lat': 46.2022},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.01,
#    'feels_like': 8.95,
#    'temp_min': 7.46,
#    'temp_max': 11.94,
#    'pressure': 1017,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437876,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377047,
#    'sunset': 1679420877},
#   'timezone': 3600,
#   'id': 2660646,
#   'name': 'Geneva',
#   'cod': 200},
#  {'coord': {'lon': 6.1333, 'lat': 46.2333},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.56,
#    'feels_like': 9.56,
#    'temp_min': 7.01,
#    'temp_max': 11.49,
#    'pressure': 1017,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377050,
#    'sunset': 1679420880},
#   'timezone': 3600,
#   'id': 2660532,
#   'name': 'Le Grand-Saconnex',
#   'cod': 200},
#  {'coord': {'lon': 6.1144, 'lat': 46.1898},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.7,
#    'feels_like': 9.7,
#    'temp_min': 7.23,
#    'temp_max': 11.71,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437886,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377055,
#    'sunset': 1679420884},
#   'timezone': 3600,
#   'id': 6691640,
#   'name': 'Lancy',
#   'cod': 200},
#  {'coord': {'lon': 6.0803, 'lat': 46.2342},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.65,
#    'feels_like': 9.65,
#    'temp_min': 7.1,
#    'temp_max': 11.58,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437799,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377063,
#    'sunset': 1679420893},
#   'timezone': 3600,
#   'id': 2659667,
#   'name': 'Meyrin',
#   'cod': 200},
#  {'coord': {'lon': 6.1, 'lat': 46.1833},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.6,
#    'feels_like': 9.6,
#    'temp_min': 7.19,
#    'temp_max': 11.67,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437893,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377058,
#    'sunset': 1679420888},
#   'timezone': 3600,
#   'id': 2659296,
#   'name': 'Onex',
#   'cod': 200},
#  {'coord': {'lon': 6.1167, 'lat': 46.1667},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.6,
#    'feels_like': 9.6,
#    'temp_min': 7.29,
#    'temp_max': 11.77,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377055,
#    'sunset': 1679420884},
#   'timezone': 3600,
#   'id': 2659190,
#   'name': 'Plan-les-Ouates',
#   'cod': 200},
#  {'coord': {'lon': 6.199, 'lat': 46.1881},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.84,
#    'feels_like': 9.84,
#    'temp_min': 7.31,
#    'temp_max': 11.78,
#    'pressure': 1017,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377035,
#    'sunset': 1679420864},
#   'timezone': 3600,
#   'id': 3209505,
#   'name': 'Thônex',
#   'cod': 200},
#  {'coord': {'lon': 6.085, 'lat': 46.217},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.58,
#    'feels_like': 9.58,
#    'temp_min': 7.1,
#    'temp_max': 11.58,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377062,
#    'sunset': 1679420891},
#   'timezone': 3600,
#   'id': 2658154,
#   'name': 'Vernier',
#   'cod': 200},
#  {'coord': {'lon': 6.1667, 'lat': 46.2833},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.12,
#    'feels_like': 9.12,
#    'temp_min': 7.46,
#    'temp_max': 11.94,
#    'pressure': 1017,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377042,
#    'sunset': 1679420872},
#   'timezone': 3600,
#   'id': 2658151,
#   'name': 'Versoix',
#   'cod': 200},
#  {'coord': {'lon': 6.1844, 'lat': 46.167},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.61,
#    'feels_like': 9.61,
#    'temp_min': 7.21,
#    'temp_max': 11.69,
#    'pressure': 1017,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6928,
#    'country': 'CH',
#    'sunrise': 1679377038,
#    'sunset': 1679420867},
#   'timezone': 3600,
#   'id': 2658143,
#   'name': 'Veyrier',
#   'cod': 200},
#  {'coord': {'lon': 7.3333, 'lat': 47.3333},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9,
#    'feels_like': 9,
#    'temp_min': 8.03,
#    'temp_max': 10.43,
#    'pressure': 1016,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6940,
#    'country': 'CH',
#    'sunrise': 1679376756,
#    'sunset': 1679420599},
#   'timezone': 3600,
#   'id': 2660207,
#   'name': 'Canton of Jura',
#   'cod': 200},
#  {'coord': {'lon': 7.3305, 'lat': 47.3543},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.38,
#    'feels_like': 9.04,
#    'temp_min': 9,
#    'temp_max': 9.78,
#    'pressure': 1018,
#    'humidity': 84,
#    'sea_level': 1018,
#    'grnd_level': 967},
#   'visibility': 10000,
#   'wind': {'speed': 1.41, 'deg': 235, 'gust': 1.6},
#   'clouds': {'all': 78},
#   'dt': 1679437894,
#   'sys': {'type': 2,
#    'id': 2076962,
#    'country': 'CH',
#    'sunrise': 1679376756,
#    'sunset': 1679420599},
#   'timezone': 3600,
#   'id': 6458744,
#   'name': 'Delémont District',
#   'cod': 200},
#  {'coord': {'lon': 7.3445, 'lat': 47.3649},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10.03,
#    'feels_like': 9.23,
#    'temp_min': 8.97,
#    'temp_max': 10.93,
#    'pressure': 1018,
#    'humidity': 82,
#    'sea_level': 1018,
#    'grnd_level': 967},
#   'visibility': 10000,
#   'wind': {'speed': 1.16, 'deg': 226, 'gust': 1.24},
#   'clouds': {'all': 95},
#   'dt': 1679437679,
#   'sys': {'type': 2,
#    'id': 2076962,
#    'country': 'CH',
#    'sunrise': 1679376753,
#    'sunset': 1679420596},
#   'timezone': 3600,
#   'id': 2661035,
#   'name': 'Delémont',
#   'cod': 200},
#  {'coord': {'lon': 7.0456, 'lat': 47.2494},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 5.35,
#    'feels_like': 3.71,
#    'temp_min': 5.02,
#    'temp_max': 6.09,
#    'pressure': 1018,
#    'humidity': 91,
#    'sea_level': 1018,
#    'grnd_level': 897},
#   'visibility': 10000,
#   'wind': {'speed': 2.07, 'deg': 228, 'gust': 2.77},
#   'clouds': {'all': 82},
#   'dt': 1679437894,
#   'sys': {'type': 1,
#    'id': 6940,
#    'country': 'CH',
#    'sunrise': 1679376825,
#    'sunset': 1679420667},
#   'timezone': 3600,
#   'id': 6458790,
#   'name': 'Franches-Montagnes District',
#   'cod': 200},
#  {'coord': {'lon': 7.0764, 'lat': 47.4147},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9.62,
#    'feels_like': 8.67,
#    'temp_min': 8.97,
#    'temp_max': 10.89,
#    'pressure': 1018,
#    'humidity': 90,
#    'sea_level': 1018,
#    'grnd_level': 966},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 222, 'gust': 2.27},
#   'clouds': {'all': 79},
#   'dt': 1679437894,
#   'sys': {'type': 2,
#    'id': 2076962,
#    'country': 'CH',
#    'sunrise': 1679376817,
#    'sunset': 1679420661},
#   'timezone': 3600,
#   'id': 6458776,
#   'name': 'Porrentruy District',
#   'cod': 200}]
